# %% [markdown]
# ## Pre-processing

# %%
import json

# %%
with open("/Users/samadkarimov/Downloads/yelp_dataset/yelp_academic_dataset_business.json") as f:
    data = [json.loads(line) for line in f]

# %%
with open("/Users/samadkarimov/Downloads/yelp_dataset/yelp_academic_dataset_review.json") as f:
    reviews = [json.loads(line) for line in f]

# %%
import pandas as pd
business_data = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8cb99f02074a> in <module>
#       1 import pandas as pd
# ----> 2 business_data = pd.DataFrame(data)
#
# NameError: name 'data' is not defined

# %%
business_data
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1       87 Grasso Plaza Shopping Center         Affton    MO       63123
# ...

# %%
business_data = business_data.dropna(subset=['categories'])
valid_rows = business_data[business_data['categories'].str.contains('Apartments')]

# %%
valid_rows = business_data[business_data['categories'].str.contains('Apartments')]; valid_rows
# Out:
#                    business_id                      name  \
# 195     x8KYhsxbufQiYIK-4MRzHQ        West Coast Roofing
# 210     UoKkgWmE9-c3wbWwO4VAVQ   Beaver Hill Condominium
# 243     qb5pyP6XOS8K2uuC4eQHmQ         Union on Fletcher
# 277     OIsLivxtTTqH7i1QISoUOQ      Villas at San Dorado
# 286     iolaqx0v6g-fymksGWIU9A     Camden Bay Apartments
# ...                        ...                       ...
# 150187  wGimCF1K63d7r6qkonMJHQ             1200 Broadway
# 150211  wz7oFpTzteQQbvMkL-nIeA      Quarter At Ybor City
# 150266  vb7t5_4aZ9yDgOMmFGYKgw  Cobb Property Management
# 150307  nMx7IAeMqy1-GfB84RnyhQ                Devonshire
# 150326  JDM7kiCEmeBc_5W-z6eZZw   2601 Parkway Apartments
#
#                          address          city state postal_code   latitude  \
# 195         910 S Santa Rita Ave        Tucson    AZ       85749  32.210447
# 210             309 Florence Ave    Jenkintown    PA       19046  40.094306
# ...

# %%
apartment_ids = valid_rows['business_id']

# %%
# Merging

# %%
reviews = pd.DataFrame(reviews)

# %%
apartments = valid_rows.merge(reviews, how='left', on='business_id')

# %% [markdown]
# ## Merging with user data

# %%
import pickle
pickle.dump(apartments, open('df.pd', 'wb'))
# apartments = pickle.load(open('df.pd', 'rb')); apartments
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ed38c7024820> in <module>
#       1 import pickle
# ----> 2 pickle.dump(apartments, open('df.pd', 'wb'))
#       3 # apartments = pickle.load(open('df.pd', 'rb')); apartments
#
# NameError: name 'apartments' is not defined

# %%
list(apartments.columns)
# Out:
# ['business_id',
#  'name',
#  'address',
#  'city',
#  'state',
#  'postal_code',
#  'latitude',
#  'longitude',
#  'stars_x',
#  'review_count',
#  'is_open',
#  'attributes',
#  'categories',
#  'hours',
#  'review_id',
#  'user_id',
#  'stars_y',
#  'useful',
#  'funny',
#  'cool',
#  'text',
#  'date']

# %%
## getting info from Users dataset

# %%
import pickle
#pickle.dump(data, open('users.pd', 'wb'))
users = pickle.load(open('users.pd', 'rb'))

# %%
list(users.columns)
# Out:
# ['user_id',
#  'name',
#  'review_count',
#  'yelping_since',
#  'useful',
#  'funny',
#  'cool',
#  'elite',
#  'friends',
#  'fans',
#  'average_stars',
#  'compliment_hot',
#  'compliment_more',
#  'compliment_profile',
#  'compliment_cute',
#  'compliment_list',
#  'compliment_note',
#  'compliment_plain',
#  'compliment_cool',
#  'compliment_funny',
#  'compliment_writer',
#  'compliment_photos']

# %%
vars = ['user_id', 'name', 'review_count', 'fans']
users2 = users[vars]
users2 = users2.rename(columns={"review_count": "user_review_count"})
users2
# Out:
#                         user_id     name  user_review_count  fans
# 0        qVc8ODYU5SZjKXVBgXdI7w   Walker                585   267
# 1        j14WgRoU_-2ZE1aw1dXrJg   Daniel               4333  3138
# 2        2WnXYQFK0hXEoTxPtV2zvg    Steph                665    52
# 3        SZDeASXq7o05mMNLshsdIA     Gwen                224    28
# 4        hA5lMy-EnncsH4JoR-hFGQ    Karen                 79     1
# ...                         ...      ...                ...   ...
# 1987892  fB3jbHi3m0L2KgGOxBv6uw  Jerrold                 23     0
# 1987893  68czcr4BxJyMQ9cJBm6C7Q     Jane                  1     0
# 1987894  1x3KMskYxOuJCjRz70xOqQ  Shomari                  4     0
# 1987895  ulfGl4tdbrH05xKzh5lnog  Susanne                  2     0
# 1987896  wL5jPrLRVCK_Pmo4lM1zpA      Isa                  2     0
#
# [1987897 rows x 4 columns]

# %%
# merging users with apartments

# %%
apartments = apartments.merge(users2, how='left', on='user_id')

# %%
apartments.head(50)
# Out:
#                business_id                   name_x                   address  \
# 0   x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing      910 S Santa Rita Ave
# 1   x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing      910 S Santa Rita Ave
# 2   x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing      910 S Santa Rita Ave
# 3   x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing      910 S Santa Rita Ave
# 4   x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing      910 S Santa Rita Ave
# 5   x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing      910 S Santa Rita Ave
# 6   x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing      910 S Santa Rita Ave
# 7   x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing      910 S Santa Rita Ave
# 8   x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing      910 S Santa Rita Ave
# 9   x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing      910 S Santa Rita Ave
# 10  x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing      910 S Santa Rita Ave
# ...

# %% [markdown]
# ### Start

# %%
import pickle
# pickle.dump(apartments, open('df.pd', 'wb'))
apartments = pickle.load(open('df.pd', 'rb')); apartments
# Out:
#                   business_id                   name_x                address  \
# 0      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 1      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 2      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 3      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 4      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# ...                       ...                      ...                    ...
# 30979  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30980  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30981  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30982  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30983  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
#
# ...

# %%
# see the nature of suspicious texts

# %%
for i in apartments[apartments.user_id=='3rqHJ7hKEAlKeHk7D4PVSQ'].text:
    print(i)
# Out:
# I have been here one year. I couldn't be more pleased. Which is not to say everything is perfect every day. But nearly so. Very, very glad I moved here.

# %%
apartments[apartments['categories'].str.contains('Roofing')]
# Out:
#                business_id              name_x               address    city  \
# 0   x8KYhsxbufQiYIK-4MRzHQ  West Coast Roofing  910 S Santa Rita Ave  Tucson
# 1   x8KYhsxbufQiYIK-4MRzHQ  West Coast Roofing  910 S Santa Rita Ave  Tucson
# 2   x8KYhsxbufQiYIK-4MRzHQ  West Coast Roofing  910 S Santa Rita Ave  Tucson
# 3   x8KYhsxbufQiYIK-4MRzHQ  West Coast Roofing  910 S Santa Rita Ave  Tucson
# 4   x8KYhsxbufQiYIK-4MRzHQ  West Coast Roofing  910 S Santa Rita Ave  Tucson
# 5   x8KYhsxbufQiYIK-4MRzHQ  West Coast Roofing  910 S Santa Rita Ave  Tucson
# 6   x8KYhsxbufQiYIK-4MRzHQ  West Coast Roofing  910 S Santa Rita Ave  Tucson
# 7   x8KYhsxbufQiYIK-4MRzHQ  West Coast Roofing  910 S Santa Rita Ave  Tucson
# 8   x8KYhsxbufQiYIK-4MRzHQ  West Coast Roofing  910 S Santa Rita Ave  Tucson
# 9   x8KYhsxbufQiYIK-4MRzHQ  West Coast Roofing  910 S Santa Rita Ave  Tucson
# 10  x8KYhsxbufQiYIK-4MRzHQ  West Coast Roofing  910 S Santa Rita Ave  Tucson
# ...

# %%
apartments[apartments['categories'].str.contains('Hotel')]
# Out:
#                   business_id                        name_x  \
# 897    -s_fY3oLwmkm1YhY38k_vA  Suburban Extended Stay Hotel
# 898    -s_fY3oLwmkm1YhY38k_vA  Suburban Extended Stay Hotel
# 899    -s_fY3oLwmkm1YhY38k_vA  Suburban Extended Stay Hotel
# 900    -s_fY3oLwmkm1YhY38k_vA  Suburban Extended Stay Hotel
# 901    -s_fY3oLwmkm1YhY38k_vA  Suburban Extended Stay Hotel
# ...                       ...                           ...
# 30893  XGGPXLaa_B2Qc79cq9YPlg               Beach House Inn
# 30894  XGGPXLaa_B2Qc79cq9YPlg               Beach House Inn
# 30895  XGGPXLaa_B2Qc79cq9YPlg               Beach House Inn
# 30896  XGGPXLaa_B2Qc79cq9YPlg               Beach House Inn
# 30897  XGGPXLaa_B2Qc79cq9YPlg               Beach House Inn
#
#                  address           city state postal_code   latitude  \
# 897          3051 Hwy 90       Avondale    LA       70094  29.909095
# 898          3051 Hwy 90       Avondale    LA       70094  29.909095
# ...

# %%
apartments[apartments['name_x'].str.contains('Storage')]
# Out:
#                   business_id         name_x            address      city  \
# 21582  g8kJe5_9r5ZM3WFeAEI2sw  Acorn Storage  641 W Franklin Rd  Meridian
# 21583  g8kJe5_9r5ZM3WFeAEI2sw  Acorn Storage  641 W Franklin Rd  Meridian
# 21584  g8kJe5_9r5ZM3WFeAEI2sw  Acorn Storage  641 W Franklin Rd  Meridian
# 21585  g8kJe5_9r5ZM3WFeAEI2sw  Acorn Storage  641 W Franklin Rd  Meridian
# 21586  g8kJe5_9r5ZM3WFeAEI2sw  Acorn Storage  641 W Franklin Rd  Meridian
#
#       state postal_code   latitude  longitude  stars_x  review_count  ...  \
# 21582    ID       83642  43.604336 -116.40231      3.0             5  ...
# 21583    ID       83642  43.604336 -116.40231      3.0             5  ...
# 21584    ID       83642  43.604336 -116.40231      3.0             5  ...
# 21585    ID       83642  43.604336 -116.40231      3.0             5  ...
# 21586    ID       83642  43.604336 -116.40231      3.0             5  ...
#
#                       user_id stars_y useful funny cool  \
# ...

# %%
apartments[apartments['categories'].str.contains('Storage')]
# Out:
#                   business_id                name_x            address  \
# 100    sKdF_rwYyLa2NM1dlG0-Sg  Riverwood Apartments     805 Kuenzli St
# 101    sKdF_rwYyLa2NM1dlG0-Sg  Riverwood Apartments     805 Kuenzli St
# 102    sKdF_rwYyLa2NM1dlG0-Sg  Riverwood Apartments     805 Kuenzli St
# 103    sKdF_rwYyLa2NM1dlG0-Sg  Riverwood Apartments     805 Kuenzli St
# 104    sKdF_rwYyLa2NM1dlG0-Sg  Riverwood Apartments     805 Kuenzli St
# ...                       ...                   ...                ...
# 21582  g8kJe5_9r5ZM3WFeAEI2sw         Acorn Storage  641 W Franklin Rd
# 21583  g8kJe5_9r5ZM3WFeAEI2sw         Acorn Storage  641 W Franklin Rd
# 21584  g8kJe5_9r5ZM3WFeAEI2sw         Acorn Storage  641 W Franklin Rd
# 21585  g8kJe5_9r5ZM3WFeAEI2sw         Acorn Storage  641 W Franklin Rd
# 21586  g8kJe5_9r5ZM3WFeAEI2sw         Acorn Storage  641 W Franklin Rd
#
#            city state postal_code   latitude   longitude  stars_x  \
# ...

# %%
apartments[apartments['categories'].str.contains('University Housing')]
# Out:
#                   business_id                name_x                address  \
# 120    xY0jpu0zzGEBr-bGBdPs-w  University Crossings     3175 JFK Boulevard
# 121    xY0jpu0zzGEBr-bGBdPs-w  University Crossings     3175 JFK Boulevard
# 122    xY0jpu0zzGEBr-bGBdPs-w  University Crossings     3175 JFK Boulevard
# 123    xY0jpu0zzGEBr-bGBdPs-w  University Crossings     3175 JFK Boulevard
# 124    xY0jpu0zzGEBr-bGBdPs-w  University Crossings     3175 JFK Boulevard
# ...                       ...                   ...                    ...
# 30929  pje0eKs-9GsdsdfKEnXzew        Roberts Realty  3229 S Brentwood Blvd
# 30930  pje0eKs-9GsdsdfKEnXzew        Roberts Realty  3229 S Brentwood Blvd
# 30931  pje0eKs-9GsdsdfKEnXzew        Roberts Realty  3229 S Brentwood Blvd
# 30932  pje0eKs-9GsdsdfKEnXzew        Roberts Realty  3229 S Brentwood Blvd
# 30933  pje0eKs-9GsdsdfKEnXzew        Roberts Realty  3229 S Brentwood Blvd
#
# ...

# %%
apartments[apartments['categories'].str.contains('Shopping')]
# Out:
#                   business_id             name_x               address  \
# 206    ARb-hdkQ7Qla0FKCo4SPcA     Rosemont Plaza  1062 E Lancaster Ave
# 207    ARb-hdkQ7Qla0FKCo4SPcA     Rosemont Plaza  1062 E Lancaster Ave
# 208    ARb-hdkQ7Qla0FKCo4SPcA     Rosemont Plaza  1062 E Lancaster Ave
# 209    ARb-hdkQ7Qla0FKCo4SPcA     Rosemont Plaza  1062 E Lancaster Ave
# 210    ARb-hdkQ7Qla0FKCo4SPcA     Rosemont Plaza  1062 E Lancaster Ave
# ...                       ...                ...                   ...
# 14879  SU-s9GD5LZ4povsx5pOS5Q  Icon In the Gulch        300 11th Ave S
# 14880  SU-s9GD5LZ4povsx5pOS5Q  Icon In the Gulch        300 11th Ave S
# 14881  SU-s9GD5LZ4povsx5pOS5Q  Icon In the Gulch        300 11th Ave S
# 14882  SU-s9GD5LZ4povsx5pOS5Q  Icon In the Gulch        300 11th Ave S
# 14883  SU-s9GD5LZ4povsx5pOS5Q  Icon In the Gulch        300 11th Ave S
#
#             city state postal_code   latitude  longitude  stars_x  \
# ...

# %%
apartments[apartments['categories'].str.contains('Financial Services')]
# Out:
#                   business_id  \
# 4200   nSwrxurgcVEz5IsAV9DPLw
# 4201   nSwrxurgcVEz5IsAV9DPLw
# 4202   nSwrxurgcVEz5IsAV9DPLw
# 4203   nSwrxurgcVEz5IsAV9DPLw
# 4204   nSwrxurgcVEz5IsAV9DPLw
# ...                       ...
# 21108  Ui5s4XGg681ayDFTItotUw
# 21109  Ui5s4XGg681ayDFTItotUw
# 21110  Ui5s4XGg681ayDFTItotUw
# 21111  Ui5s4XGg681ayDFTItotUw
# 21112  Ui5s4XGg681ayDFTItotUw
#
#                                                   name_x  \
# 4200                                      TCS Management
# 4201                                      TCS Management
# 4202                                      TCS Management
# 4203                                      TCS Management
# 4204                                      TCS Management
# ...                                                  ...
# 21108  South Tampa Real Estate & Beyond - Mike + Mich...
# 21109  South Tampa Real Estate & Beyond - Mike + Mich...
# 21110  South Tampa Real Estate & Beyond - Mike + Mich...
# ...

# %%
apartments.categories.unique()
# Out:
# array(['Apartments, Roofing, Real Estate, Home Services',
#        'Real Estate, Apartments, Home Services',
#        'Home Services, Real Estate, Apartments',
#        'Apartments, Real Estate, Home Services',
#        'Real Estate, Apartments, Home Services, Local Services, Self Storage',
#        'Apartments, University Housing, Home Services, Real Estate, Property Management',
#        'Apartments, Real Estate, Home Services, Property Management',
#        'Real Estate, Home Services, Apartments',
#        'University Housing, Real Estate, Home Services, Apartments',
#        'Apartments, Home Services, Real Estate',
#        'Commercial Real Estate, Shopping, Apartments, Real Estate, Home Services',
#        'Apartments, Shopping Centers, Property Management, Local Services, Commercial Real Estate, Real Estate, Home Services, Shopping',
#        'Home Services, Apartments, Real Estate',
# ...

# %%
# users with few reviews

# %%
apartments[apartments.user_id=='R_HjJW2Z53WbXxblfBbtYA'] ## other reviews are not shown. dataset is small.
# Out:
#                business_id                name_x            address  \
# 32  OIsLivxtTTqH7i1QISoUOQ  Villas at San Dorado  10730 N Oracle Rd
#
#           city state postal_code   latitude   longitude  stars_x  \
# 32  Oro Valley    AZ       85737  32.398472 -110.954261      4.0
#
#     review_count  ...                 user_id stars_y useful funny cool  \
# 32             7  ...  R_HjJW2Z53WbXxblfBbtYA     3.0      3     0    0
#
#                                                  text                 date  \
# 32  Place is okay, not really "luxury" as advertis...  2017-08-09 17:17:34
#
#     name_y  user_review_count  fans
# 32   Linda                8.0   0.0
#
# [1 rows x 25 columns]

# %%
# users with only one review count and those who gave 5

# %%
one_reviews = apartments[apartments.user_review_count==1]; one_reviews # 4974 with 1 reviews
# Out:
#                   business_id                    name_x  \
# 13     x8KYhsxbufQiYIK-4MRzHQ        West Coast Roofing
# 19     UoKkgWmE9-c3wbWwO4VAVQ   Beaver Hill Condominium
# 22     qb5pyP6XOS8K2uuC4eQHmQ         Union on Fletcher
# 24     qb5pyP6XOS8K2uuC4eQHmQ         Union on Fletcher
# 27     qb5pyP6XOS8K2uuC4eQHmQ         Union on Fletcher
# ...                       ...                       ...
# 30939  wGimCF1K63d7r6qkonMJHQ             1200 Broadway
# 30941  wGimCF1K63d7r6qkonMJHQ             1200 Broadway
# 30950  wz7oFpTzteQQbvMkL-nIeA      Quarter At Ybor City
# 30958  vb7t5_4aZ9yDgOMmFGYKgw  Cobb Property Management
# 30959  vb7t5_4aZ9yDgOMmFGYKgw  Cobb Property Management
#
#                       address        city state postal_code   latitude  \
# 13       910 S Santa Rita Ave      Tucson    AZ       85749  32.210447
# 19           309 Florence Ave  Jenkintown    PA       19046  40.094306
# 22     3600 East Fletcher Ave       Tampa    FL       33613  28.069967
# ...

# %%
bad_apartments = one_reviews[one_reviews.stars_x<3]; bad_apartments # 3307 with 1 reviews for bad apartments
# Out:
#                   business_id                    name_x  \
# 13     x8KYhsxbufQiYIK-4MRzHQ        West Coast Roofing
# 22     qb5pyP6XOS8K2uuC4eQHmQ         Union on Fletcher
# 24     qb5pyP6XOS8K2uuC4eQHmQ         Union on Fletcher
# 27     qb5pyP6XOS8K2uuC4eQHmQ         Union on Fletcher
# 107    sKdF_rwYyLa2NM1dlG0-Sg      Riverwood Apartments
# ...                       ...                       ...
# 30929  pje0eKs-9GsdsdfKEnXzew            Roberts Realty
# 30939  wGimCF1K63d7r6qkonMJHQ             1200 Broadway
# 30941  wGimCF1K63d7r6qkonMJHQ             1200 Broadway
# 30958  vb7t5_4aZ9yDgOMmFGYKgw  Cobb Property Management
# 30959  vb7t5_4aZ9yDgOMmFGYKgw  Cobb Property Management
#
#                       address         city state postal_code   latitude  \
# 13       910 S Santa Rita Ave       Tucson    AZ       85749  32.210447
# 22     3600 East Fletcher Ave        Tampa    FL       33613  28.069967
# 24     3600 East Fletcher Ave        Tampa    FL       33613  28.069967
# ...

# %%
potential_fakeX = one_reviews[one_reviews.stars_y==5.0]; potential_fakeX # 1288 reviews giving 5 stars (around 20 per cent of all the sample)
# Out:
#                   business_id                    name_x  \
# 24     qb5pyP6XOS8K2uuC4eQHmQ         Union on Fletcher
# 28     OIsLivxtTTqH7i1QISoUOQ      Villas at San Dorado
# 31     OIsLivxtTTqH7i1QISoUOQ      Villas at San Dorado
# 40     iolaqx0v6g-fymksGWIU9A     Camden Bay Apartments
# 47     iolaqx0v6g-fymksGWIU9A     Camden Bay Apartments
# ...                       ...                       ...
# 30789  DZu3Fh9YejCK5YNyxUx4Bg          Burlington House
# 30896  XGGPXLaa_B2Qc79cq9YPlg           Beach House Inn
# 30939  wGimCF1K63d7r6qkonMJHQ             1200 Broadway
# 30950  wz7oFpTzteQQbvMkL-nIeA      Quarter At Ybor City
# 30959  vb7t5_4aZ9yDgOMmFGYKgw  Cobb Property Management
#
#                         address           city state postal_code   latitude  \
# 24       3600 East Fletcher Ave          Tampa    FL       33613  28.069967
# 28            10730 N Oracle Rd     Oro Valley    AZ       85737  32.398472
# ...

# %%
potential_fakeY = one_reviews[one_reviews.stars_y==1.0]; potential_fakeY # 2844 rows givin 1 stars (around 55 per cent)
# Out:
#                   business_id                   name_x  \
# 13     x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing
# 19     UoKkgWmE9-c3wbWwO4VAVQ  Beaver Hill Condominium
# 27     qb5pyP6XOS8K2uuC4eQHmQ        Union on Fletcher
# 44     iolaqx0v6g-fymksGWIU9A    Camden Bay Apartments
# 66     iolaqx0v6g-fymksGWIU9A    Camden Bay Apartments
# ...                       ...                      ...
# 30915  lna-UaP3ZH0EjFgYNSOQZw            Marina's Edge
# 30922  pje0eKs-9GsdsdfKEnXzew           Roberts Realty
# 30926  pje0eKs-9GsdsdfKEnXzew           Roberts Realty
# 30929  pje0eKs-9GsdsdfKEnXzew           Roberts Realty
# 30941  wGimCF1K63d7r6qkonMJHQ            1200 Broadway
#
#                         address         city state postal_code   latitude  \
# 13         910 S Santa Rita Ave       Tucson    AZ       85749  32.210447
# 19             309 Florence Ave   Jenkintown    PA       19046  40.094306
# 27       3600 East Fletcher Ave        Tampa    FL       33613  28.069967
# ...

# %%
potential_fake2 = bad_apartments[bad_apartments.stars_y==5.0]; potential_fake2 # 425 givin 5 stars (around 15 per cent)
# Out:
#                   business_id                      name_x  \
# 24     qb5pyP6XOS8K2uuC4eQHmQ           Union on Fletcher
# 174    n2Va0mKydUWM-Y4fv1pOtA              YOUnion @ Reno
# 314    BOSfORSF0k2qjHKFovbOuA             Privateer Place
# 415    V85fGg0cb0B4gWEWWgKaGQ                Canal Square
# 696    _nvLQbSUXdBsMu2OFK5HdA     The Loop- Coastal Ridge
# ...                       ...                         ...
# 30772  6DlzMV3TOMj34Z7_7Vl9fQ        ARK Neshaminy Villas
# 30782  AN-QAwTTNCQOKbfimx1G4A  Woodberry Woods Apartments
# 30789  DZu3Fh9YejCK5YNyxUx4Bg            Burlington House
# 30939  wGimCF1K63d7r6qkonMJHQ               1200 Broadway
# 30959  vb7t5_4aZ9yDgOMmFGYKgw    Cobb Property Management
#
#                         address          city state postal_code   latitude  \
# 24       3600 East Fletcher Ave         Tampa    FL       33613  28.069967
# 174          2780 Enterprise Rd          Reno    NV       89512  39.551173
# ...

# %%
# looking at the texts of likely fake reviews

# %%
for i in potential_fake2[potential_fake2.user_id=='0pDOO3YKUgVYX-qOvIl6Ng'].text:
    print(i)
# Out:
# I rented from Cobb Property Management for almost 5 years and I could not be more satisfied. Kathy, my property manager, was on the ball with all maintenance requests during that time, and the contractors that were sent my way for repairs were local, beyond friendly, punctual, and thorough. The home I rented was nestled in a perfect neighborhood for my small children, just down the road from the elementary school, and it was not the only Cobb rental in the area! They have tons of nice homes for rent in my area (Vail/Corona de Tucson), as well as Tucson, Green Valley, etc. No lack of choice! My family counts itself as lucky to have been referred to them, as we are military, and it just so happens that Cobb Property Management is owned by an Air Force retiree (making he and his employees quite aware of our unique needs). Highly recommend renting from them!

# %%
# good apartments but bad reviews (with 1 review counts)

# %%
good_apartments = one_reviews[one_reviews.stars_x>3.5]; good_apartments # 504 revies
# Out:
#                   business_id  \
# 28     OIsLivxtTTqH7i1QISoUOQ
# 31     OIsLivxtTTqH7i1QISoUOQ
# 148    wR8V8u3_wv-yjR-CIHyY0Q
# 150    wR8V8u3_wv-yjR-CIHyY0Q
# 157    wR8V8u3_wv-yjR-CIHyY0Q
# ...                       ...
# 30261  iQihUkQP34YDdINihpLfow
# 30268  3Y4t274EGZ9_EZ0ShXKrcA
# 30580  aSicU_9mV62C9jvYBX9iqw
# 30581  aSicU_9mV62C9jvYBX9iqw
# 30896  XGGPXLaa_B2Qc79cq9YPlg
#
#                                                   name_x  \
# 28                                  Villas at San Dorado
# 31                                  Villas at San Dorado
# 148                               The Collins Apartments
# 150                               The Collins Apartments
# 157                               The Collins Apartments
# ...                                                  ...
# 30261          Somerset Lakes Apartments in Indianapolis
# 30268                                   Foxland Crossing
# 30580  The Flats at Silo Bend Apartments by Lincoln P...
# ...

# %%
potential_fake3 = good_apartments[good_apartments.stars_y==1.0]; potential_fake3 # 65 rows
# Out:
#                   business_id                                      name_x  \
# 277    NQn_dGaMlvbQGwgAA6t85w                The Glen At Shawmont Station
# 437    MHs3YnWPruw8iss1oZkYvg                   Lenox Village Town Center
# 438    MHs3YnWPruw8iss1oZkYvg                   Lenox Village Town Center
# 445    MHs3YnWPruw8iss1oZkYvg                   Lenox Village Town Center
# 597    j5EOSkPcu0ehV2WB8U0xdg  The Hamptons at Woodland Pointe Apartments
# ...                       ...                                         ...
# 28910  8C2whAiBromuprsIyNvxLA               M South by Matrix Residential
# 29977  iWTNgIfbaa_BEbd2lVFLMQ                       The Laurel Apartments
# 29979  iWTNgIfbaa_BEbd2lVFLMQ                       The Laurel Apartments
# 30097  HjYXFlkfuLbQMfX_Ase-fA                      Latitude 39 Apartments
# 30134  RKH5Pu9zhXR82GbE3cBlWw            Mount Laurel Crossing Apartments
#
#                        address          city state postal_code   latitude  \
# ...

# %%
for i in potential_fake3[potential_fake3.user_id=='zMIL3R_rlX0tgQ_499XBxg'].text: # one stars don't seem to be fake (but word count may matter)
    print(i)
# Out:
# Horrible place to live cigarette butts everywhere. Noisy disrespectful neighbors management does nothing to resolve the issue. It's a no smoking complex but my apartment is filled with smoke to the point we've been to my child's doctor four times in a month over her asthma. Dog poop is everywhere. We can't wait to leave this place. It's definitely not worth two thousand a month. It's horrible not to mention leaky walls and birds that live on your porch you can't even sit on your porch without poop. The shrubbery isn't maintained and ants are rampant everywhere since our move in day. Keep driving pass.

# %% [markdown]
# ## Preliminary Analysis - to be repeated for the subset of tampa

# %% [markdown]
# ## Getting positive and negative words

# %%
import pandas as pd

# %%
# creating good_bad categorical reviews from 1,2 and 4,5 stars

# %%
apt = apartments[apartments['good_bad'].isin([0,1])];apt # ommitting 3 rating apartments (not bad nor good)
# Out:
#                   business_id              name_x               address  \
# 0      x8KYhsxbufQiYIK-4MRzHQ  West Coast Roofing  910 S Santa Rita Ave
# 1      x8KYhsxbufQiYIK-4MRzHQ  West Coast Roofing  910 S Santa Rita Ave
# 2      x8KYhsxbufQiYIK-4MRzHQ  West Coast Roofing  910 S Santa Rita Ave
# 3      x8KYhsxbufQiYIK-4MRzHQ  West Coast Roofing  910 S Santa Rita Ave
# 4      x8KYhsxbufQiYIK-4MRzHQ  West Coast Roofing  910 S Santa Rita Ave
# ...                       ...                 ...                   ...
# 30973  nMx7IAeMqy1-GfB84RnyhQ          Devonshire  1100 Devonshire E Dr
# 30974  nMx7IAeMqy1-GfB84RnyhQ          Devonshire  1100 Devonshire E Dr
# 30975  nMx7IAeMqy1-GfB84RnyhQ          Devonshire  1100 Devonshire E Dr
# 30976  nMx7IAeMqy1-GfB84RnyhQ          Devonshire  1100 Devonshire E Dr
# 30977  nMx7IAeMqy1-GfB84RnyhQ          Devonshire  1100 Devonshire E Dr
#
#             city state postal_code   latitude   longitude  stars_x  \
# ...

# %%
stars = apt['good_bad']
text = apt['text']

# %%
## Pipelines and model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
ng_tfidf = TfidfVectorizer(ngram_range=(3,3), stop_words='english')
tdi_text = ng_tfidf.fit(text)

# %%
from sklearn.base import BaseEstimator
import pandas as pd
from sklearn.base import TransformerMixin

class ToText(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X = pd.DataFrame(X)
        X2 = X[X['good_bad'].isin([0,1])]
        return X2['text']

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer


vect_text = Pipeline([
    ('to_text', ToText()),
    ('tfidfvectorizer', TfidfVectorizer(ngram_range=(3,3), stop_words='english')),
])

# %%
vectorized = vect_text.fit_transform(apartments)

# %%
from sklearn.naive_bayes import MultinomialNB
bayes_model = MultinomialNB(alpha=0.1).fit(vectorized, stars)

# %%
log_prob = bayes_model.feature_log_prob_
polarity1 = log_prob[1]/log_prob[0]
words = ng_tfidf.get_feature_names()
words_probs = list(zip(words, polarity1))
words_probs = sorted(words_probs, key=lambda x: x[1], reverse=True); words_probs

# %%
polarity2 = log_prob[0]/log_prob[1]
words_probs2 = list(zip(words, polarity2))
words_probs2 = sorted(words_probs2, key=lambda x: x[1], reverse=True); words_probs2

# %%
pos_words, neg_words = words_probs2[:20], words_probs[:20]

# %%
pos_words
# Out:
# [('philly home girls', 1.4880264759393647),
#  ('blue horizon management', 1.3400551000099197),
#  ('nashville apartment locators', 1.3325065728345424),
#  ('home girls team', 1.3292440028972476),
#  ('beach house inn', 1.326471090541033),
#  ('hanover north broad', 1.3239208017632493),
#  ('cross town movers', 1.3162914006685618),
#  ('pacific crest hotel', 1.292591828819596),
#  ('time home buyers', 1.2797709679270257),
#  ('warm mushroom salad', 1.2675942350607117),
#  ('wonderful place stay', 1.265977043826511),
#  ('quiet clean friendly', 1.2589515898657777),
#  ('home buying process', 1.257509447785451),
#  ('horizon management company', 1.2566779490669067),
#  ('walking distance beach', 1.2496146146004752),
#  ('months like report', 1.242872750215708),
#  ('3rd street flats', 1.2399687342184254),
#  ('kristin philly home', 1.2395749211154918),
#  ('living great location', 1.2377542912586899),
#  ('looking buy sell', 1.2371166568042402)]

# %%
neg_words
# Out:
# [('stay away place', 1.3433140924308984),
#  ('don waste money', 1.3356592139416228),
#  ('return phone calls', 1.3032842209385145),
#  ('60 day notice', 1.2976109936118747),
#  ('extended stay america', 1.29522786857593),
#  ('worst property management', 1.2893533754592224),
#  ('just want money', 1.2769008141388385),
#  ('60 days notice', 1.275675596547281),
#  ('small claims court', 1.2749017873478494),
#  ('better places live', 1.2689967008537055),
#  ('philly apartment company', 1.2683538895038755),
#  ('worst customer service', 1.2662225156962195),
#  ('worst living experience', 1.2629339455465391),
#  ('don care tenants', 1.262901129944384),
#  ('worst place live', 1.261970500841797),
#  ('far far away', 1.2612203336333503),
#  ('horrible customer service', 1.2591716664292572),
#  ('pmc property group', 1.2589011673708843),
#  ('make mistake did', 1.2583653575052565),
#  ('don let fool', 1.2552645109296774)]

# %% [markdown]
# ### Looking at one apartment ( get its suspicious reviews and NLP)

# %%
# More preprocessing of the main data first

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
# apartments = apartments[apartments.review_count>9] - not necessary. it reduces the num of obs

# %%
def my_recode(x):
    if x > 3:
        return 1 
    elif x < 3:
        return 0

# %%
def recode(x):
    if x == 3:
        return 1

# %%
apartments['good_bad'] = apartments['stars_x'].apply(my_recode); apartments
# Out:
#                   business_id                   name_x                address  \
# 0      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 1      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 2      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 3      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 4      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# ...                       ...                      ...                    ...
# 30979  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30980  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30981  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30982  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30983  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
#
# ...

# %%
apartments['neutral'] = apartments['stars_x'].apply(recode); apartments
# Out:
#                   business_id                   name_x                address  \
# 0      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 1      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 2      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 3      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 4      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# ...                       ...                      ...                    ...
# 30979  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30980  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30981  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30982  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30983  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
#
# ...

# %%
def len_text(x):
    if len(x) < 100:
        return 1

# %%
apartments['short_reviews'] = apartments['text'].apply(len_text)
apartments[apartments['short_reviews']==1]; apartments
# Out:
#                   business_id                   name_x                address  \
# 0      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 1      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 2      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 3      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 4      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# ...                       ...                      ...                    ...
# 30979  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30980  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30981  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30982  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30983  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
#
# ...

# %% [markdown]
# ### Getting the fake reviews

# %%
apartments
# Out:
#                   business_id                   name_x                address  \
# 0      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 1      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 2      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 3      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 4      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# ...                       ...                      ...                    ...
# 30979  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30980  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30981  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30982  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30983  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
#
# ...

# %%
# bad apartments but good reviews from those with very few general reviews

# %%
fake_reviews = apartments[(apartments.good_bad==0) & (apartments.stars_y==5) & (apartments.user_review_count<4)]
fake_user_id = fake_reviews['user_id']

# %%
def myfunc(x):
    for i in fake_user_id:
        if x == i:
            return 1

apartments['fake'] = apartments['user_id'].apply(myfunc)

# %%
len(apartments[apartments['fake']==1])
# Out:
# 1052

# %%
# bad apartments but good reviews where number of character per review is lower than 100

# %%
fake_reviews2 = apartments[(apartments.good_bad==0) & (apartments.stars_y==5) & (apartments.short_reviews==1)]
fake_user_id2 = fake_reviews2['user_id']

# %%
def myfunc2(x):
    for i in fake_user_id2:
        if x == i:
            return 1
apartments['fake2'] = apartments['user_id'].apply(myfunc2)

# %%
len(apartments[apartments['fake2']==1])
# Out:
# 109

# %%
# good apartments but 1 star reviews from those with only few total review

# %%
fake_reviews3 = apartments[(apartments.good_bad==1) & (apartments.stars_y==1) & (apartments.user_review_count<4)]
fake_user_id3 = fake_reviews3['user_id']

# %%
def myfunc3(x):
    for i in fake_user_id3:
        if x == i:
            return 1
apartments['fake3'] = apartments['user_id'].apply(myfunc3)

# %%
len(apartments[apartments['fake3']==1])
# Out:
# 547

# %%
# good apartments but 1 star reviews with only less than 100 characters

# %%
fake_reviews4 = apartments[(apartments.good_bad==1) & (apartments.stars_y==1) & (apartments.short_reviews==1)]
fake_user_id4 = fake_reviews4['user_id']

# %%
def myfunc4(x):
    for i in fake_user_id4:
        if x == i:
            return 1
apartments['fake4'] = apartments['user_id'].apply(myfunc4)

# %%
len(apartments[apartments['fake4']==1])
# Out:
# 51

# %%
apartments
# Out:
#                   business_id                   name_x                address  \
# 0      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 1      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 2      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 3      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 4      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# ...                       ...                      ...                    ...
# 30979  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30980  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30981  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30982  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30983  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
#
# ...

# %%
# creating one 'fake' variable out of four categories

# %%
apartments['fake_all'] = apartments['fake'].apply(lambda x: 1 if x==1 else 0) | apartments['fake2'].apply(lambda x: 1 if x==1 else 0) | apartments['fake3'].apply(lambda x: 1 if x==1 else 0) | apartments['fake4'].apply(lambda x: 1 if x==1 else 0)

# %%
len(apartments[apartments['fake_all']==1])
# Out:
# 1700

# %%
# saving the apartments data as apartments2

# %%
apartments2 = apartments

# %%
def good(x):
    if x > 3:
        return 1 
    else:
        return 0
apartments['good'] = apartments['stars_y'].apply(good)
def bad(x):
    if x < 3:
        return 1
    else:
        return 0
apartments['bad'] = apartments['stars_y'].apply(bad)

def neutr(x):
    if x == 3:
        return 1
    else: return 0
apartments['neutr'] = apartments['stars_y'].apply(neutr)

# %%
import pickle
#pickle.dump(apartments2, open('df2.pd', 'wb'))
apartments = pickle.load(open('df2.pd', 'rb')); apartments
# Out:
#                   business_id                   name_x                address  \
# 0      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 1      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 2      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 3      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# 4      x8KYhsxbufQiYIK-4MRzHQ       West Coast Roofing   910 S Santa Rita Ave
# ...                       ...                      ...                    ...
# 30979  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30980  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30981  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30982  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
# 30983  JDM7kiCEmeBc_5W-z6eZZw  2601 Parkway Apartments  2601 Pennsylvania Ave
#
# ...

# %% [markdown]
# ## APARTMENTS IN TAMPA

# %%
tampa = apartments[apartments.city=='Tampa']; tampa
# Out:
#                   business_id                name_x                 address  \
# 20     qb5pyP6XOS8K2uuC4eQHmQ     Union on Fletcher  3600 East Fletcher Ave
# 21     qb5pyP6XOS8K2uuC4eQHmQ     Union on Fletcher  3600 East Fletcher Ave
# 22     qb5pyP6XOS8K2uuC4eQHmQ     Union on Fletcher  3600 East Fletcher Ave
# 23     qb5pyP6XOS8K2uuC4eQHmQ     Union on Fletcher  3600 East Fletcher Ave
# 24     qb5pyP6XOS8K2uuC4eQHmQ     Union on Fletcher  3600 East Fletcher Ave
# ...                       ...                   ...                     ...
# 30948  wz7oFpTzteQQbvMkL-nIeA  Quarter At Ybor City         1800 E Palm Ave
# 30949  wz7oFpTzteQQbvMkL-nIeA  Quarter At Ybor City         1800 E Palm Ave
# 30950  wz7oFpTzteQQbvMkL-nIeA  Quarter At Ybor City         1800 E Palm Ave
# 30951  wz7oFpTzteQQbvMkL-nIeA  Quarter At Ybor City         1800 E Palm Ave
# 30952  wz7oFpTzteQQbvMkL-nIeA  Quarter At Ybor City         1800 E Palm Ave
#
# ...

# %%
len(tampa[tampa['good_bad']==1])
# Out:
# 861

# %%
len(tampa[tampa['good']==1])
# Out:
# 1260

# %%
len(tampa[tampa['bad']==1])
# Out:
# 1876

# %%
tampa.name_x.unique()
# Out:
# array(['Union on Fletcher', 'Camden Bay Apartments',
#        'Manor Riverwalk Luxury Apartments by TRG Management Company',
#        'The Ivy', 'Visconti at Westshore', 'Portofino Apartment Homes',
#        'The Marq Highland Park', 'Jefferson Westshore',
#        'Grand Pavilion Condominiums by Greystar Real Estate',
#        'Audubon Village-Cortland', 'Reflections of Tampa',
#        'The Preserve at Mobbly Bay', 'Lantower Brandon Crossroads',
#        '5 West', 'Brandon Oaks Apartments', 'Countrywood Apartments',
#        'Campus Club North', 'The Lakes at Brandon West',
#        'Suburban Extended Stay Hotel Airport', '5 Oaks at Westchase',
#        'Carrollwood Station', 'The Pointe',
#        'Colonial Grand at Hampton Preserve',
#        'Landmark at Grand Palms Apartment Homes', 'Society Westshore',
#        'Urban Oasis Furnished Apartments', 'River View Apartments',
#        'Luxe at 1820', 'Aurora', 'Flats at Seminole Heights by Pinnacle',
# ...

# %%
print('Enter apartment name: ')
name = input()
# Out:
# Enter apartment name:
# Camden Bay Apartments

# %%
data = tampa[tampa.name_x == name]; data
# Out:
#                business_id                 name_x                   address  \
# 35  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 36  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 37  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 38  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 39  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 40  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 41  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 42  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 43  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 44  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 45  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# ...

# %% [markdown]
# ### Fake Review Count

# %%
str(int((len(data[data.fake_all==1]) / len(data)) * 100)) + '%'
# Out:
# '10%'

# %%
# Eliminating fake reviews

# %%
data2 = data[data.fake_all==0] ; data2
# Out:
#                business_id                 name_x                   address  \
# 36  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 37  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 38  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 39  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 40  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 41  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 42  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 43  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 45  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 46  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# 47  iolaqx0v6g-fymksGWIU9A  Camden Bay Apartments  11302 W Hillsborough Ave
# ...

# %%
data3 = data2[data2.neutr==0]

# %%
stars = data3['good']
text = data3['text']

# %%
stars
# Out:
# 36    0
# 37    0
# 38    1
# 39    1
# 40    1
# 41    1
# 42    1
# 43    0
# 45    0
# 46    1
# 47    1
# 49    1
# 50    1
# 51    1
# 52    0
# 53    1
# 54    1
# 55    0
# 56    1
# 57    0
# 58    1
# 59    1
# 60    1
# 61    1
# 62    0
# 63    1
# 64    1
# 65    0
# 67    1
# 68    1
# 69    1
# 72    1
# 73    1
# 74    0
# 75    1
# 76    1
# 77    1
# 78    1
# 79    0
# 80    0
# 81    1
# 82    0
# 83    0
# 85    1
# 86    1
# 87    0
# 88    1
# 90    0
# 91    1
# 92    0
# 93    1
# 94    0
# Name: good, dtype: int64

# %%
from sklearn.base import BaseEstimator
from sklearn.base import TransformerMixin

class ToText(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X = pd.DataFrame(X)
        X2 = X[X['neutr']==0]
        text = [i for i in X2['text']]
        return text

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
ng_tfidf = TfidfVectorizer(ngram_range=(3,3),max_features=30, stop_words='english')
tdi_text = ng_tfidf.fit(text)

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer


vect_text = Pipeline([
    ('to_text', ToText()),
    ('tfidfvectorizer', TfidfVectorizer(ngram_range=(3,3), max_features=30,  stop_words='english')),
])

# %%
vectorized = vect_text.fit_transform(data3)

# %%
from sklearn.naive_bayes import MultinomialNB
bayes_model = MultinomialNB(alpha=0.1).fit(vectorized, stars)

# %%
log_prob = bayes_model.feature_log_prob_
polarity1 = log_prob[1]/log_prob[0]
words = ng_tfidf.get_feature_names()
words_probs = list(zip(words, polarity1))
words_probs = sorted(words_probs, key=lambda x: x[1], reverse=True); words_probs
# Out:
# [('deal monday really', 1.8509283703815267),
#  ('dealing disgusting reported', 1.8509283703815267),
#  ('saying deal monday', 1.8509283703815267),
#  ('sit couch brush', 1.8509283703815267),
#  ('bedroom incredibly loud', 1.633914687600697),
#  ('camden bay dr', 1.633914687600697),
#  ('couple bedroom incredibly', 1.633914687600697),
#  ('lived couple bedroom', 1.633914687600697),
#  ('months lived couple', 1.633914687600697),
#  ('counter space sized', 1.3784876215786512),
#  ('day pornographic dvd', 1.3784876215786512),
#  ('desk 20 minutes', 1.3784876215786512),
#  ('desk area computer', 1.3784876215786512),
#  ('didn affect window', 1.3784876215786512),
#  ('didn block light', 1.3784876215786512),
#  ('different built company', 1.3784876215786512),
#  ('different initially rented', 1.3784876215786512),
#  ('room people got', 1.3784876215786512),
#  ('row parking spaces', 1.3784876215786512),
#  ('running meth lab', 1.3784876215786512),
# ...

# %%
polarity2 = log_prob[0]/log_prob[1]
words_probs2 = list(zip(words, polarity2))
words_probs2 = sorted(words_probs2, key=lambda x: x[1], reverse=True); words_probs2
# Out:
# [('great place live', 3.8832934899834823),
#  ('camden bay apartments', 3.203459433719316),
#  ('camden bay staff', 2.8147321636915157),
#  ('say good things', 1.8903680201907649),
#  ('experience camden bay', 1.3682951824649505),
#  ('counter space sized', 0.7254327020033701),
#  ('day pornographic dvd', 0.7254327020033701),
#  ('desk 20 minutes', 0.7254327020033701),
#  ('desk area computer', 0.7254327020033701),
#  ('didn affect window', 0.7254327020033701),
#  ('didn block light', 0.7254327020033701),
#  ('different built company', 0.7254327020033701),
#  ('different initially rented', 0.7254327020033701),
#  ('room people got', 0.7254327020033701),
#  ('row parking spaces', 0.7254327020033701),
#  ('running meth lab', 0.7254327020033701),
#  ('said sorry closed', 0.7254327020033701),
#  ('say guy probably', 0.7254327020033701),
#  ('season idea 3rd', 0.7254327020033701),
#  ('sit desk 20', 0.7254327020033701),
#  ('sitting couches talking', 0.7254327020033701),
# ...

# %%
pos_words, neg_words = words_probs2[:20], words_probs[:20]

# %%
pos_words
# Out:
# [('great place live', 3.8832934899834823),
#  ('camden bay apartments', 3.203459433719316),
#  ('camden bay staff', 2.8147321636915157),
#  ('say good things', 1.8903680201907649),
#  ('experience camden bay', 1.3682951824649505),
#  ('counter space sized', 0.7254327020033701),
#  ('day pornographic dvd', 0.7254327020033701),
#  ('desk 20 minutes', 0.7254327020033701),
#  ('desk area computer', 0.7254327020033701),
#  ('didn affect window', 0.7254327020033701),
#  ('didn block light', 0.7254327020033701),
#  ('different built company', 0.7254327020033701),
#  ('different initially rented', 0.7254327020033701),
#  ('room people got', 0.7254327020033701),
#  ('row parking spaces', 0.7254327020033701),
#  ('running meth lab', 0.7254327020033701),
#  ('said sorry closed', 0.7254327020033701),
#  ('say guy probably', 0.7254327020033701),
#  ('season idea 3rd', 0.7254327020033701),
#  ('sit desk 20', 0.7254327020033701)]

# %%
neg_words
# Out:
# [('deal monday really', 1.8509283703815267),
#  ('dealing disgusting reported', 1.8509283703815267),
#  ('saying deal monday', 1.8509283703815267),
#  ('sit couch brush', 1.8509283703815267),
#  ('bedroom incredibly loud', 1.633914687600697),
#  ('camden bay dr', 1.633914687600697),
#  ('couple bedroom incredibly', 1.633914687600697),
#  ('lived couple bedroom', 1.633914687600697),
#  ('months lived couple', 1.633914687600697),
#  ('counter space sized', 1.3784876215786512),
#  ('day pornographic dvd', 1.3784876215786512),
#  ('desk 20 minutes', 1.3784876215786512),
#  ('desk area computer', 1.3784876215786512),
#  ('didn affect window', 1.3784876215786512),
#  ('didn block light', 1.3784876215786512),
#  ('different built company', 1.3784876215786512),
#  ('different initially rented', 1.3784876215786512),
#  ('room people got', 1.3784876215786512),
#  ('row parking spaces', 1.3784876215786512),
#  ('running meth lab', 1.3784876215786512)]

# %% [markdown]
# ### With only Count Vectorizer - No Bayesian

# %%
data4 = data2[data2.neutr==1]

# %%
text2 = data4.text

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
neutr_words = CountVectorizer(max_features=30, 
                             ngram_range=(3,3), 
                             stop_words='english')

# %%
neutr_words.fit(text2)
# Out:
# CountVectorizer(max_features=30, ngram_range=(3, 3), stop_words='english')

# %%
print(neutr_words.get_feature_names())
# Out:
# ['100 month signed', 'machine gonna start', 'maintenance guys ok', 'making good choice', 'maritza supposed weeks', 'month paying 100', 'month pros cons', 'month signed asked', 'moving hate charged', 'moving thank reaching', 'new gate installed', 'new soon hate', 'ok sure fix', 'ones feeling like', 'paying 100 month', 'place new soon', 'posted concerns community', 'property worries looking', 'pros cons weigh', 'reading camden way', 'reading concern bad', 'review reading concern', 'review thought making', 'safe iam reading', 'water sewer trash', 'water washing machine', 'way gate working', 'website surprisingly ones', 'weeks iam afraid', 'weigh long shot']

# %%
text2[71]
# Out:
# "Hi my name is Maritza, I supposed to move in two weeks now iam afraid because of all the review I am have been reading. I concern about all the bad review .I thought I was making a good choice. I was leaving the another complex because the gate was always broken and didn't feel safe. Now iam reading that Camden is the same way with there gate not working.\n\nI am happy to hear that a new gate has been installed and also heard that there  is security that goes around the property . I have no worries now. Looking forward to moving in . Thank you for reaching out to me. I will keep everyone posted"

# %%
text2[89]
# Out:
# 'At first it was great. Slowly they have increased our "fees" every month and we are paying over $100 more a month then we signed up for. We asked for an explanation why the water and sewer and trash fees keep going up and they will not give me an answer. Once I posted my concerns on the community website, surprisingly we are not the only ones feeling like we are being taken advantage of. The maintenance guys are ok, but not sure why they cannot fix my bathroom faucet or why I cannot get cold water to my washing machine.. gonna start looking for some place new soon. I hate moving but hate being over charged every month. It has its pros but the cons out weigh them by a long shot.'

# %%
print(neutr_words.transform(text2))
# Out:
#   (0, 3)	1
#   (0, 4)	1
#   (0, 9)	1
#   (0, 10)	1
#   (0, 17)	1
#   (0, 19)	1
#   (0, 20)	1
#   (0, 21)	1
#   (0, 22)	1
#   (0, 23)	1
#   (0, 26)	1
#   (0, 28)	1
#   (1, 0)	1
#   (1, 1)	1
#   (1, 2)	1
#   (1, 5)	1
#   (1, 6)	1
#   (1, 7)	1
#   (1, 8)	1
#   (1, 11)	1
#   (1, 12)	1
#   (1, 13)	1
#   (1, 14)	1
#   (1, 15)	1
#   (1, 16)	1
#   (1, 18)	1
#   (1, 24)	1
#   (1, 25)	1
#   (1, 27)	1
#   (1, 29)	1

# %%
len(data[data.fake_all==1]) / len(data)
# Out:
# 0.1
