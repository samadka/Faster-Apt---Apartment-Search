# %%
import pandas as pd
import requests
import streamlit as st
import plotly.express as px
import datetime
import pickle
import matplotlib.pyplot as plt
import plotly.express as px

# %%
tampa = pickle.load(open('tampa.pd', 'rb'))

# %%
plt.hist(tampa.fake_all)
plt.title("Histogram of Suspicious Reviews")
plt.xlabel("Regular vs. Suspicious Reviews")
plt.ylabel("Number of Reviews")
plt.savefig('histogram.png',)

# %%
plt.scatter(tampa.stars_x,tampa.review_count)
plt.title("Scatter plot of review count and apartment stars")
plt.xlabel("Apartment Stars")
plt.ylabel("Review Count")
plt.savefig('scatterplot.png')
